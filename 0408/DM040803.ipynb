# %% [markdown]
# <font color = "#CC3D3D">
# ## Automated Feature Engineering with Featuretools

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import featuretools as ft

# %% [markdown]
# ### Read Data

# %%
df_train = pd.read_csv('X_train_hds.csv', encoding='cp949', dtype={'goodcd': 'category'})
df_test = pd.read_csv('X_test_hds.csv', encoding='cp949', dtype={'goodcd': 'category'})
# Assign a unique ID for each transaction 
df = pd.concat([df_train, df_test]).reset_index(drop=True).reset_index().rename(columns={'index': 'transid'})
df.head()
# Out:
#    transid  custid           sales_date  sales_time str_nm         goodcd  \
# 0        0       0  2000-06-25 00:00:00        1212    무역점  2116050008000
# 1        1       0  2000-06-25 00:00:00        1242    무역점  4125440008000
# 2        2       0  2000-08-26 00:00:00        1810     본점  2116052008000
# 3        3       0  2000-08-26 00:00:00        1830     본점  4106430119900
# 4        4       0  2000-09-03 00:00:00        1802    무역점  2139141008000
#
#   brd_nm corner_nm pc_nm part_nm team_nm buyer_nm  import_flg  tot_amt  \
# 0  에스티로더   수입종합화장품   화장품    명품잡화   잡화가용팀      화장품           1    90000
# 1    시슬리   수입종합화장품   화장품    명품잡화   잡화가용팀      화장품           1    39000
# 2   크리니크   수입종합화장품   화장품    잡화파트   잡화가용팀      화장품           1   175000
# 3     듀퐁      수입의류  명품토탈    잡화파트   잡화가용팀     수입명품           1   455000
# 4     랑콤   수입종합화장품   화장품    명품잡화   잡화가용팀      화장품           0   100000
#
#    dis_amt  net_amt  inst_mon  inst_fee
# 0     9000    81000         3         0
# 1     3900    35100         1         0
# 2    17500   157500         3         0
# 3    45500   409500         3         0
# 4    10000    90000         3         0

# %% [markdown]
# ### Prepare data

# %%
# A dataframe to create a feature matrix for each customer 
cu = pd.DataFrame({'custid': df.custid.unique()})

# Specify a dictionary with all the entities
entities = {
    "cust": (cu, "custid"),
    "trans": (df, "transid")
}

# Specify how the entities are related
relationships = [
    ("cust", "custid", "trans", "custid")
]

# %% [markdown]
# ### Run Deep Feature Synthesis

# %%
# %%time
derived_features, _ = ft.dfs(entities=entities, relationships=relationships, target_entity="cust")
derived_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49995 entries, 0 to 49994
# Data columns (total 67 columns):
# SUM(trans.sales_time)                    49995 non-null int64
# SUM(trans.import_flg)                    49995 non-null int64
# SUM(trans.tot_amt)                       49995 non-null int64
# SUM(trans.dis_amt)                       49995 non-null int64
# SUM(trans.net_amt)                       49995 non-null int64
# SUM(trans.inst_mon)                      49995 non-null int64
# SUM(trans.inst_fee)                      49995 non-null int64
# STD(trans.sales_time)                    48850 non-null float64
# STD(trans.import_flg)                    48850 non-null float64
# STD(trans.tot_amt)                       48850 non-null float64
# STD(trans.dis_amt)                       48850 non-null float64
# STD(trans.net_amt)                       48850 non-null float64
# STD(trans.inst_mon)                      48850 non-null float64
# STD(trans.inst_fee)                      48850 non-null float64
# MAX(trans.sales_time)                    49995 non-null int64
# MAX(trans.import_flg)                    49995 non-null int64
# MAX(trans.tot_amt)                       49995 non-null int64
# MAX(trans.dis_amt)                       49995 non-null int64
# MAX(trans.net_amt)                       49995 non-null int64
# MAX(trans.inst_mon)                      49995 non-null int64
# MAX(trans.inst_fee)                      49995 non-null int64
# SKEW(trans.sales_time)                   47421 non-null float64
# SKEW(trans.import_flg)                   47421 non-null float64
# SKEW(trans.tot_amt)                      47421 non-null float64
# SKEW(trans.dis_amt)                      47421 non-null float64
# SKEW(trans.net_amt)                      47421 non-null float64
# SKEW(trans.inst_mon)                     47421 non-null float64
# SKEW(trans.inst_fee)                     47421 non-null float64
# MIN(trans.sales_time)                    49995 non-null int64
# MIN(trans.import_flg)                    49995 non-null int64
# MIN(trans.tot_amt)                       49995 non-null int64
# MIN(trans.dis_amt)                       49995 non-null int64
# MIN(trans.net_amt)                       49995 non-null int64
# MIN(trans.inst_mon)                      49995 non-null int64
# MIN(trans.inst_fee)                      49995 non-null int64
# MEAN(trans.sales_time)                   49995 non-null float64
# MEAN(trans.import_flg)                   49995 non-null float64
# MEAN(trans.tot_amt)                      49995 non-null float64
# MEAN(trans.dis_amt)                      49995 non-null float64
# MEAN(trans.net_amt)                      49995 non-null float64
# MEAN(trans.inst_mon)                     49995 non-null float64
# MEAN(trans.inst_fee)                     49995 non-null float64
# COUNT(trans)                             49995 non-null int64
# NUM_UNIQUE(trans.str_nm)                 49995 non-null int64
# NUM_UNIQUE(trans.goodcd)                 49995 non-null int64
# NUM_UNIQUE(trans.brd_nm)                 49995 non-null int64
# NUM_UNIQUE(trans.corner_nm)              49995 non-null int64
# NUM_UNIQUE(trans.pc_nm)                  49995 non-null int64
# NUM_UNIQUE(trans.part_nm)                49995 non-null int64
# NUM_UNIQUE(trans.team_nm)                49995 non-null int64
# NUM_UNIQUE(trans.buyer_nm)               49995 non-null int64
# MODE(trans.str_nm)                       49995 non-null object
# MODE(trans.goodcd)                       49995 non-null object
# MODE(trans.brd_nm)                       49995 non-null object
# MODE(trans.corner_nm)                    49995 non-null object
# MODE(trans.pc_nm)                        49995 non-null object
# MODE(trans.part_nm)                      49995 non-null object
# MODE(trans.team_nm)                      49995 non-null object
# MODE(trans.buyer_nm)                     49995 non-null object
# NUM_UNIQUE(trans.DAY(sales_date))        49995 non-null int64
# NUM_UNIQUE(trans.YEAR(sales_date))       49995 non-null int64
# NUM_UNIQUE(trans.MONTH(sales_date))      49995 non-null int64
# NUM_UNIQUE(trans.WEEKDAY(sales_date))    49995 non-null int64
# MODE(trans.DAY(sales_date))              49995 non-null int64
# MODE(trans.YEAR(sales_date))             49995 non-null int64
# MODE(trans.MONTH(sales_date))            49995 non-null int64
# MODE(trans.WEEKDAY(sales_date))          49995 non-null int64
# dtypes: float64(21), int64(38), object(8)
# memory usage: 25.9+ MB
# CPU times: user 4min 55s, sys: 1.62 s, total: 4min 57s
# Wall time: 4min 56s

# %%
derived_features.head()
# Out:
#         SUM(trans.sales_time)  SUM(trans.import_flg)  SUM(trans.tot_amt)  \
# custid
# 0                       19328                      7             1742000
# 1                       39810                     11             2772100
# 2                       16908                      1             3750850
# 3                       48122                      0             2300500
# 4                        5736                      1             1045000
#
#         SUM(trans.dis_amt)  SUM(trans.net_amt)  SUM(trans.inst_mon)  \
# custid
# 0                   174200             1567800                   31
# 1                    56630             2715470                   64
# 2                   255090             3495760                   38
# 3                    91660             2208840                   80
# 4                    21800             1023200                   18
#
#         SUM(trans.inst_fee)  STD(trans.sales_time)  STD(trans.import_flg)  \
# custid
# 0                         0             266.443786               0.504525
# 1                         0             263.383020               0.503831
# 2                         3             352.567002               0.301511
# 3                         3             274.230199               0.000000
# 4                         2              21.087121               0.500000
#
#         STD(trans.tot_amt)               ...                 \
# custid                                   ...
# 0            118540.518581               ...
# 1            109270.336393               ...
# 2            791625.029320               ...
# 3            191949.716985               ...
# 4            250313.636598               ...
#
#         MODE(trans.team_nm)  MODE(trans.buyer_nm)  \
# custid
# 0                     잡화가용팀                   화장품
# 1                     의류패션팀                  수입명품
# 2                     잡화가용팀                    가전
# 3                     잡화가용팀                   스포츠
# 4                     의류패션팀                캐릭터캐주얼
#
#         NUM_UNIQUE(trans.DAY(sales_date))  NUM_UNIQUE(trans.YEAR(sales_date))  \
# custid
# 0                                       7                                   2
# 1                                      12                                   2
# 2                                       7                                   2
# 3                                      11                                   2
# 4                                       2                                   1
#
#         NUM_UNIQUE(trans.MONTH(sales_date))  \
# custid
# 0                                         5
# 1                                         7
# 2                                         6
# 3                                         9
# 4                                         1
#
#         NUM_UNIQUE(trans.WEEKDAY(sales_date))  MODE(trans.DAY(sales_date))  \
# custid
# 0                                           5                            3
# 1                                           5                           13
# 2                                           3                           27
# 3                                           5                           20
# 4                                           2                           27
#
#         MODE(trans.YEAR(sales_date))  MODE(trans.MONTH(sales_date))  \
# custid
# 0                               2000                              9
# 1                               2000                              6
# 2                               2000                              8
# 3                               2000                              7
# 4                               2000                              7
#
#         MODE(trans.WEEKDAY(sales_date))
# custid
# 0                                     6
# 1                                     5
# 2                                     2
# 3                                     3
# 4                                     3
#
# [5 rows x 67 columns]

# %%
# One-hot encoding for categorical features
derived_features.drop(['MODE(trans.goodcd)'], axis=1, inplace=True)
derived_features = pd.get_dummies(derived_features).reset_index()

# Fill NA
derived_features.fillna(0, inplace=True)

# Split Data
X_train = pd.DataFrame({'custid': df_train.custid.unique()})
X_train = pd.merge(X_train, derived_features, how='left')

X_test = pd.DataFrame({'custid': df_test.custid.unique()})
X_test = pd.merge(X_test, derived_features, how='left')

# Remove unnecessary features
IDtest = X_test.custid;
X_train.drop(['custid'], axis=1, inplace=True)
X_test.drop(['custid'], axis=1, inplace=True)
y_train = pd.read_csv('y_train_hds.csv').gender

# %% [markdown]
# ### Build Models

# %%
# Learn XGB
from xgboost import XGBClassifier
import sys, warnings
if not sys.warnoptions: warnings.simplefilter("ignore")

model = XGBClassifier(random_state=0, n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)

# %% [markdown]
# ### Make Submissions

# %%
pred = model.predict_proba(X_test)[:,1]
fname = 'submission_DFS.csv'
submissions = pd.concat([IDtest, pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))
# Out:
# 'submission_DFS.csv' is ready to submit.

# %% [markdown]
# <font color = "#CC3D3D">
# ## End
